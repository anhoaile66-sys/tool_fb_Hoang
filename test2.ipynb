# %%
import json
device_id = "QK8TEMKZMBYHPV6P"
with  open(f"Zalo_base/device_status_{device_id}.json", 'r', encoding='utf-8') as f:
    data = json.load(f)
data['active'] = False
with open(f"Zalo_base/device_status_{device_id}.json", 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)

# %%
import json
device_id = "QK8TEMKZMBYHPV6P"
with  open(f"Zalo_base/device_status_{device_id}.json", 'r', encoding='utf-8') as f:
    data = json.load(f)
data['active'] = True
with open(f"Zalo_base/device_status_{device_id}.json", 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)
